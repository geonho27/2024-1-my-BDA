# %% [markdown]
# <a href="https://colab.research.google.com/github/geonho27/2024-1-my-BDA/blob/main/inclass/02w_0318_mon_dataframe_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 빅데이터분석프로그래밍

# %% [markdown]
# ## 파이썬 설치 확인

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(np.__version__)
print(pd.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.25.2
# 1.5.3

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.5 MB/s eta 0:00:00
# ...

# %%
#해상도 선명하게
# %config lnlineeBack.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.plot('그래프 제목')
plt.plot('간단한 그래프')
plt.show()

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(titanic, x = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(titanic, x = 'class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(titanic, x = 'class', hue = 'alive') # x축 class alive별 색 표현
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
titanic.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.values
# Out:
# array([3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2,
#        3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3,
#        3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1,
#        3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3,
# ...

# %%
titanic["pclass"].unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
titanic[['pclass', 'who']].values
# Out:
# array([[3, 'man'],
#        [1, 'woman'],
#        [3, 'woman'],
#        ...,
#        [3, 'woman'],
#        [1, 'man'],
#        [3, 'man']], dtype=object)

# %%
titanic.groupby('sex').count()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
titanic.groupby('class').count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  186    216    216   216       214  216
# Second       184     184  184  173    184    184   184       184  184
# Third        491     491  491  355    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          216   175          214    216    216
# Second         184    16          184    184    184
# Third          491    12          491    491    491

# %%
sns.barplot(x='sex', y="survived", data=titanic);

# %%
sns.barplot(x='pclass', y="survived", data=titanic);

# %%
sns.barplot(x='pclass', y='survived', hue="sex", data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %% [markdown]
# ### 단원4 데이터 데이터프레임의 세계로!!:

# %%
import pandas as pd

df = pd.DataFrame({"name": ["김지훈", "이유진", "박동현", "김진지"],
                   "english": [90, 80, 60, 70],
                   "math": [50, 60, 100, 200]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김진지       70   200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   english  4 non-null      int64
#  2   math     4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#          english        math
# count   4.000000    4.000000
# mean   75.000000  102.500000
# std    12.909944   68.495742
# min    60.000000   50.000000
# 25%    67.500000   57.500000
# 50%    75.000000   80.000000
# 75%    82.500000  125.000000
# max    90.000000  200.000000

# %%
df.describe(include = 'all')
# Out:
#        name    english        math
# count     4   4.000000    4.000000
# unique    4        NaN         NaN
# top     김지훈        NaN         NaN
# freq      1        NaN         NaN
# mean    NaN  75.000000  102.500000
# std     NaN  12.909944   68.495742
# min     NaN  60.000000   50.000000
# 25%     NaN  67.500000   57.500000
# 50%     NaN  75.000000   80.000000
# 75%     NaN  82.500000  125.000000
# max     NaN  90.000000  200.000000

# %% [markdown]
# ### 특정 변수의 값 추출하기

# %%
sum(df["english"])
# Out:
# 300

# %%
sum(df['english']) / len(df)
# Out:
# 75.0

# %%
df.sum()
# Out:
# name       김지훈이유진박동현김진지
# english             300
# math                410
# dtype: object

# %%
df.sum(numeric_only=True)
# Out:
# english    300
# math       410
# dtype: int64

# %%
df.sum(axis=0, numeric_only=True)
# Out:
# english    300
# math       410
# dtype: int64

# %%
df.sum(axis=1, numeric_only=True)
# Out:
# 0    140
# 1    140
# 2    160
# 3    270
# dtype: int64

# %%
df.sum(axis="columns", numeric_only=True)
# Out:
# 0    140
# 1    140
# 2    160
# 3    270
# dtype: int64

# %%
df.sum(axis="index", numeric_only=True)
# Out:
# english    300
# math       410
# dtype: int64

# %%
df.mean(axis="columns", numeric_only=True)
# Out:
# 0     70.0
# 1     70.0
# 2     80.0
# 3    135.0
# dtype: float64

# %%
df.mean(axis="index", numeric_only=True)
# Out:
# english     75.0
# math       102.5
# dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({"제품": ["사과", "딸기", "수박"],
                   "가격": [18000, 1500, 3000],
                   "판매량": [24, 38, 13]})
df
# Out:
#    제품     가격  판매량
# 0  사과  18000   24
# 1  딸기   1500   38
# 2  수박   3000   13

# %%
sum(df["가격"])
# Out:
# 22500

# %%
sum(df["가격"]) / len(df)
# Out:
# 7500.0

# %%
sum(df["판매량"])
# Out:
# 75

# %%
sum(df["판매량"]) / len(df)
# Out:
# 25.0

# %% [markdown]
# ## 4-3 외부 데이터 이용하기  - 축적된 시험 성적 데이터를 불러오자!

# %%
df_exam = pd.read_excel('excel_exam (2).xlsx') # 엑셀 파일을
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
sum(df_exam['english']) / 20
# Out:
# 84.9

# %%
sum(df_exam['english']) / len(df_exam)
# Out:
# 84.9

# %%
df_exam['english'].mean()
# Out:
# 84.9

# %%
# 과학 성적 평균
print(sum(df_exam['science']) / 20)
print(sum(df_exam['science']) / len(df_exam))
print(df_exam['science'].mean())
# Out:
# 59.45
# 59.45
# 59.45

# %% [markdown]
# ### 엑셀 파일의 첫 번째 행이 변수명이 아니라면?

# %%
df_exam_novar = pd.read_excel('excel_exam_novar.xlsx')
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam_novar = pd.read_excel('excel_exam_novar.xlsx', header = None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %% [markdown]
# #### 엑셀 파일에 시트가 여러 개 있다면??

# %%
df_exam = pd.read_excel('excel_exam (2).xlsx', sheet_name = 'Sheet2')
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1   100      100       98
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_exam = pd.read_excel('excel_exam (2).xlsx', sheet_name = 'Sheet33')
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1   100      100       98
# 1   2       1    90       90       90
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_csv_exam = pd.read_csv('exam.csv')
df_csv_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_csv_exam.to_csv("kokoko.csv")

# %%
df_csv_exam.to_csv("kokoko.csv", index = False)

# %% [markdown]
# ### 정리하기

# %%
# 1. 데이터 프레임 만들기
import pandas as pd

df = pd.DataFrame({"name": ["김지훈", "이유진", "박동현", "김진지"],
                   "english": [90, 80, 60, 70],
                   "math": [50, 60, 100, 200]})
# 2. 외부 데이터 이용하기

# 엑셀 파일 불러오기
df_exam = pd.read_excel('excel_exam (2).xlsx')

# CSV파일 불러오기
df_csv_exam = pd.read_csv('exam.csv')

# CSV 파일로 저장하기
df_midterm = pd.DataFrame({'english': [90, 80, 60, 70],
                           'math': [50, 60, 100, 20],
                           'nclass': [1, 1, 2, 2]})
df_midterm.to_csv('output_newdata2.csv')
df_midterm.to_csv('output_newdata2.csv', index = False)
